# %% [markdown]
# <a href="https://colab.research.google.com/github/carloscifuentesingsoft1560-cyber/Redes_neuronales/blob/main/cargar_multiples_dataset_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.datasets import cifar100

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data(label_mode='fine')
# Out:
# ...
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 323s 2us/step

# %%
print (x_train.shape)
print (y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
num_image = 40
plt.imshow(x_train[num_image])
print(y_train[num_image])
# Out:
# [78]

# %%
# !wget --no-check-certificate https://storage.googleapis.com/platzi-tf2/cifar100_labels.json \
    -O /tmp/cifar100_labels.json
# Out:
# --2026-05-05 10:40:16--  https://storage.googleapis.com/platzi-tf2/cifar100_labels.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 192.178.218.207, 172.253.62.207, 172.253.122.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|192.178.218.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1436 (1.4K) [application/json]
# Saving to: ‘/tmp/cifar100_labels.json’
#
# /tmp/cifar100_label 100%[===================>]   1.40K  --.-KB/s    in 0s
#
# 2026-05-05 10:40:16 (17.4 MB/s) - ‘/tmp/cifar100_labels.json’ saved [1436/1436]

# %%
import json
with open('/tmp/cifar100_labels.json', 'r') as fine_label:
  cifar100_labels = json.load(fine_label)

# %%
num_labe = 78
plt.imshow(x_train[num_image])
print(cifar100_labels[num_labe])
# Out:
# snake
